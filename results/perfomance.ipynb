# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob, os
plt.style.use('ggplot')
# %matplotlib inline
color = dict(boxes='DarkGreen', whiskers='DarkOrange',medians='DarkBlue', caps='Gray')

# %%
os.chdir("/home/mosorio/iaa2/results/best")
columns = glob.glob("yuan*.txt")
columns.sort()
print (columns)
for file in columns:
    column = file.split('/')[-1].split('.')[0]
    dfalpha = pd.read_csv(file)
boxs = pd.concat([pd.read_csv(item, names=[item[:-4]]) for item in columns], axis=1)
p = boxs.plot.box()
p
plt.savefig('/home/mosorio/magister/iaa/iaa_emergency_routes_paper/images/yuan.pdf')
boxs.describe()
# Out:
# ['yuan-grade1.txt', 'yuan-grade2.txt', 'yuan-grade3.txt', 'yuan-grade4.txt']
#        yuan-grade1  yuan-grade2  yuan-grade3  yuan-grade4
# count   200.000000   200.000000   200.000000   200.000000
# mean      3.192416     3.588757     4.880685     6.654578
# std       0.007426     0.082409     0.067439     0.323117
# min       3.132390     3.419030     4.548850     6.365130
# 25%       3.193330     3.628570     4.815710     6.470350
# 50%       3.193330     3.628570     4.894220     6.488960
# 75%       3.193330     3.628570     4.953900     6.978330
# max       3.193330     3.628570     4.953900     7.468140

# %%
os.chdir("/home/mosorio/iaa2/results/best")
columns = glob.glob("peuco*.txt")
columns.sort()
print (columns)
for file in columns:
    column = file.split('/')[-1].split('.')[0]
    dfalpha = pd.read_csv(file)
boxs = pd.concat([pd.read_csv(item, names=[item[:-4]]) for item in columns], axis=1)
p = boxs.plot.box()
p
plt.savefig('/home/mosorio/penco.pdf')
boxs.describe()
# Out:
# ['peuco-p1.txt', 'peuco-p2.txt', 'peuco-p3.txt', 'peuco-p4.txt']
#          peuco-p1    peuco-p2    peuco-p3    peuco-p4
# count  200.000000  200.000000  200.000000  200.000000
# mean    33.069817   38.250532   38.819404   43.093132
# std      4.612457    6.206329    6.245782    7.412785
# min     26.659000   30.554500   30.632200   34.278600
# 25%     29.986600   34.317400   34.487800   38.468600
# 50%     31.363900   36.213800   36.747600   40.304050
# 75%     34.152800   39.182575   40.256275   44.579225
# max     52.429100   63.668400   66.094200   76.007800

# %%
os.chdir("/home/mosorio/iaa2/results/starts_filter")
columns = glob.glob("*p1.txt")
columns.sort()
print (columns)
for file in columns:
    column = file.split('/')[-1].split('.')[0]
    dfalpha = pd.read_csv(file)
boxs = pd.concat([pd.read_csv(item, names=[item[:-4]]) for item in columns], axis=1)
p = boxs.plot.box()
p
plt.savefig('/home/mosorio/p1-penco.pdf')
boxs.describe()
# Out:
# ['1-p1.txt', '25-p1.txt', '44-p1.txt']
#              1-p1       25-p1       44-p1
# count  200.000000  200.000000  200.000000
# mean    33.069817   29.639420   18.813761
# std      4.612457    4.548205    4.797721
# min     26.659000   22.587800   13.561500
# 25%     29.986600   25.931700   15.076300
# 50%     31.363900   28.757300   18.005900
# 75%     34.152800   31.786225   19.754400
# max     52.429100   47.029900   42.158900

# %%
os.chdir("/home/mosorio/iaa2/results/starts_filter")
columns = glob.glob("*p2.txt")
columns.sort()
print (columns)
for file in columns:
    column = file.split('/')[-1].split('.')[0]
    dfalpha = pd.read_csv(file)
boxs = pd.concat([pd.read_csv(item, names=[item[:-4]]) for item in columns], axis=1)
p = boxs.plot.box()
p
plt.savefig('/home/mosorio/p2-penco.pdf')
boxs.describe()
# Out:
# ['1-p2.txt', '25-p2.txt', '44-p2.txt']
#              1-p2       25-p2       44-p2
# count  200.000000  200.000000  200.000000
# mean    38.250532   33.891029   20.846148
# std      6.206329    5.984826    5.720610
# min     30.554500   24.765000   14.587800
# 25%     34.317400   29.521500   16.222400
# 50%     36.213800   33.053800   20.011300
# 75%     39.182575   36.646600   22.123600
# max     63.668400   56.975700   46.963000

# %%
os.chdir("/home/mosorio/iaa2/results/starts_filter")
columns = glob.glob("*p3.txt")
columns.sort()
print (columns)
for file in columns:
    column = file.split('/')[-1].split('.')[0]
    dfalpha = pd.read_csv(file)
boxs = pd.concat([pd.read_csv(item, names=[item[:-4]]) for item in columns], axis=1)
p = boxs.plot.box()
p
plt.savefig('/home/mosorio/p3-penco.pdf')
boxs.describe()
# Out:
# ['1-p3.txt', '25-p3.txt', '44-p3.txt']
#              1-p3       25-p3       44-p3
# count  200.000000  200.000000  159.000000
# mean    38.819404   34.926179   22.050294
# std      6.245782    5.747995    5.858183
# min     30.632200   25.999600   15.768800
# 25%     34.487800   31.309600   17.668200
# 50%     36.747600   33.855000   20.928100
# 75%     40.256275   37.986675   23.108950
# max     66.094200   57.212300   48.627900

# %%
os.chdir("/home/mosorio/iaa2/results/starts_filter")
columns = glob.glob("*p4.txt")
columns.sort()
print (columns)
for file in columns:
    column = file.split('/')[-1].split('.')[0]
    dfalpha = pd.read_csv(file)
boxs = pd.concat([pd.read_csv(item, names=[item[:-4]]) for item in columns], axis=1)
p = boxs.plot.box()
p
plt.savefig('/home/mosorio/p4-penco.pdf')
boxs.describe()
# Out:
# ['1-p4.txt', '25-p4.txt', '44-p4.txt']
#              1-p4       25-p4       44-p4
# count  200.000000  200.000000  200.000000
# mean    43.093132   40.974249   23.645370
# std      7.412785    6.975320    6.978726
# min     34.278600   30.346200   16.230800
# 25%     38.468600   35.699950   18.147000
# 50%     40.304050   39.776800   22.435900
# 75%     44.579225   44.507000   25.009500
# max     76.007800   68.194300   60.338200
